# %%
import pandas as pd
import os, json

# %%
read = pd.read_csv("imageScraper.csv")

# %%
read.head()
# Out:
#   web-scraper-order                            web-scraper-start-url  \
# 0  1667844196-15761  https://www.thespruce.com/plants-a-to-z-5116344
# 1  1667844199-15762  https://www.thespruce.com/plants-a-to-z-5116344
# 2  1667844201-15763  https://www.thespruce.com/plants-a-to-z-5116344
# 3  1667844204-15764  https://www.thespruce.com/plants-a-to-z-5116344
# 4  1667844207-15765  https://www.thespruce.com/plants-a-to-z-5116344
#
#                                                 link  \
# 0                    Zz Plant Zamioculcas zamiifolia
# 1                     Zygopetalum Orchid Zygopetalum
# 2             Zonal Geranium Pelargonium and hybrids
# 3  Zinfin Doll Hydrangea Hydrangea paniculata 'SM...
# 4               Zigzag Plant Euphorbia tithymaloides
#
#                                            link-href  \
# 0  https://www.thespruce.com/zz-zanzibar-gem-plan...
# 1  https://www.thespruce.com/zygopetalum-orchid-g...
# 2  https://www.thespruce.com/growing-and-caring-f...
# ...

# %%
read["image-src"]
# Out:
# 0       https://www.thespruce.com/thmb/0rMxxsuf6p4D1ci...
# 1       https://www.thespruce.com/thmb/0GZ3XtJ11t9tXwQ...
# 2       https://www.thespruce.com/thmb/EWD4eYEyqDwkPVd...
# 3       https://www.thespruce.com/thmb/klgZBLY9u3r4FXK...
# 4       https://www.thespruce.com/thmb/_Sf-5-27ZRhBVfp...
#                               ...
# 1318    https://www.thespruce.com/thmb/9_obEgwLX2nxDyX...
# 1319    https://www.thespruce.com/thmb/4SPsqza4RH8j5Gp...
# 1320    https://www.thespruce.com/thmb/iXIPd9Hklebxj9v...
# 1321    https://www.thespruce.com/thmb/Sc54Y1EEq_WI3mA...
# 1322    https://www.thespruce.com/thmb/oA9Bq1QgujDJeCQ...
# Name: image-src, Length: 1323, dtype: object

# %%
reverse_df = read.iloc[::-1]

# %%
reverse_df
# Out:
#      web-scraper-order                            web-scraper-start-url  \
# 1322  1667847670-17092  https://www.thespruce.com/plants-a-to-z-5116344
# 1321  1667847667-17091  https://www.thespruce.com/plants-a-to-z-5116344
# 1320  1667847665-17090  https://www.thespruce.com/plants-a-to-z-5116344
# 1319  1667847662-17089  https://www.thespruce.com/plants-a-to-z-5116344
# 1318  1667847660-17088  https://www.thespruce.com/plants-a-to-z-5116344
# ...                ...                                              ...
# 4     1667844207-15765  https://www.thespruce.com/plants-a-to-z-5116344
# 3     1667844204-15764  https://www.thespruce.com/plants-a-to-z-5116344
# 2     1667844201-15763  https://www.thespruce.com/plants-a-to-z-5116344
# 1     1667844199-15762  https://www.thespruce.com/plants-a-to-z-5116344
# 0     1667844196-15761  https://www.thespruce.com/plants-a-to-z-5116344
#
#                                                    link  \
# ...

# %%
reverse_df.to_csv("New_imageScraper.csv")

# %%
plantAfeter = pd.read_csv("PlantsInfo_after.csv")

# %%
plantAfeter
# Out:
#       Unnamed: 0                                        Common Name  \
# 0              0                                             Abelia
# 1              1      Giant hyssop, hummingbird mint, licorice mint
# 2              2  Batik iris, Batik German iris, Batik bearded iris
# 3              3                                             Quinoa
# 4              4       Radish, common radish, garden radish, rabone
# ...          ...                                                ...
# 1322        1322     Purple leaf sand cherry, plum leaf sand cherry
# 1323        1323                      Pussy willow, glaucous willow
# 1324        1324                           Painted daisy, pyrethrum
# 1325        1325  Quaking aspen, trembling aspen, American aspen...
# 1326        1326                               Quick Fire hydrangea
#
#                                       Botanical Name          Family  \
# 0                                             Abelia  Caprifoliaceae
# ...

# %%
plantAfeter.sort_values('Common Name')
# Out:
#       Unnamed: 0                                 Common Name  \
# 986          986  'Black Knight' delphinium, candle larkspur
# 375          375                  'Bloodgood' Japanese maple
# 677          677                       'Early Harvest' apple
# 811          811                      'Golden Oriole' azalea
# 1054        1054          'Miss Kim' lilac, Manchurian lilac
# ...          ...                                         ...
# 362          362                       Zinfin Doll hydrangea
# 253          253                                Zoysia grass
# 364          364                                         NaN
# 518          518                                         NaN
# 1048        1048                                         NaN
#
#                                   Botanical Name         Family  \
# 986             Delphinium elatum 'Black Knight'            NaN
# 375                    Acer palmatum 'Bloodgood'      Aceraceae
# ...
