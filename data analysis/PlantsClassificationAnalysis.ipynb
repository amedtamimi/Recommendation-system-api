# %%
import pandas as pd

# %%
r = pd.read_csv("PlantsInfo_after.csv",encoding= 'unicode_escape')

# %%
df = pd.DataFrame(r)

# %%
df
# Out:
#                                             Common Name  \
# 0                                              Broccoli
# 1         Cordyline, Hawaiian ti plant, good luck plant
# 2     Angelâs trumpet, pricklyburr, downy thorn ap...
# 3                                                Dahlia
# 4                                           Mastic Tree
# ...                                                 ...
# 1296  Hoptree, common hoptree, stinking ash, skunk b...
# 1297       Zigzag plant, red bird flower, fiddle flower
# 1298                            Love-in-a-mist, nigella
# 1299          Autograph tree, balsam apple, pitch apple
# 1300                             The President clematis
#
#                                          Botanical Name         Family  \
# 0                        Brassica oleracea var. italica   Brassicaceae
# 1                                  Cordyline terminalis   Asparagaceae
# 2                        DaturaÂ inoxia, Datura innoxia     Solanaceae
# ...

# %%
bloom = (df["Bloom Time"].unique())

# %%
len(bloom)
# Out:
# 259

# %%
bloom
# Out:
# array([nan, 'Summer', 'Summer, fall', 'Spring', 'Spring, summer', 'March',
#        'Summer (second year)', 'Late summer to early fall',
#        'Winter, Spring', 'Spring to late summer', 'Winter',
#        'June through October', 'Spring to fall', 'June to September',
#        'Summer to fall', 'Summer to frost', 'Early spring, May',
#        'Spring to summer', 'Summer (rarely blooms)', 'Sporadic',
#        'March to April', 'Late spring', 'April', 'Spring, summer, fall',
#        'Late spring, early summer', 'May to June', 'May', 'Fall',
#        'Late winter to early spring', 'Spring; rarely blooms indoors',
#        'Late Summer', 'Rarely blooms indoors', 'Very occasional',
#        'Late spring to early fall', 'Early spring', 'June',
#        'Blooms once only', 'Early summer to fall', 'None',
#        'Late spring, early summer, and late summer', 'Rarely flowers',
#        'Blooms once; timing varies', 'Mid-spring to early fall',
# ...

# %%
bloom[2]
# Out:
# 'Summer, fall'

# %%
sun = df["Sun Exposure"].unique()

# %%
sun
# Out:
# array(['Full sun', 'Full-sun, partial sun', 'Full',
#        'Partial sun to partial shade', 'Partial, shade',
#        'Full sun to part shade', 'Full sun, partial sun',
#        'Sun to partial shade', 'Full, Partial, Shade', 'Partial shade',
#        'Full sun (tolerates part shade/light woodland)', 'Full, partial',
#        'Full sun, partial shade',
#        'Partial (outdoor); bright, indirect light (indoors)', 'Full Sun',
#        'Partial', 'Full sun to partial shade',
#        'Full sun to light/part shade', 'Part shade, Full sun',
#        'Partial shade to full shade', 'Full sun to partial sun',
#        'Full or partial', 'Full Sun- Part Shade', 'Full to partial sun',
#        'Part shade to full shade', 'Bright, indirect light',
#        'Filtered, bright sun', 'Partial, Full',
#        'Bright indirect light; resents direct sunlight', 'Full, Partial',
#        'Partial to full shade', 'Full sun to part sun',
# ...

# %%
df['Sun Exposure']["'Bright indirect light indoors'"]

# %%
type = (df["Plant Type"].unique())

# %%
len(type)
# Out:
# 382

# %%
type[191]
# Out:
# 'Herbaceous perennial, or woody shrub'

# %%
type
# Out:
# array(['Biennial, annual, vegetable', 'Evergreen shrub',
#        'Herbaceous, perennial', 'Perennial', 'Broadleaf Evergreen',
#        'Perennial, herbaceous, rhizome',
#        'Perennial, clustered parlour palm, reed palm, cane palm',
#        'Deciduous shrub/ tree', 'Vegetable', 'Biennial, vegetable',
#        'Fruit, tree, perennial', 'Perennial, Vine', 'Shrub', 'Succulent',
#        'Herbaceous perennial', 'Evergreen tree', 'Deciduous shrub',
#        'Tree', 'Annual, fruit', 'Creeping perennial grass',
#        'Perennial, annual', 'Perennial ornamental grass',
#        'Broadleaf evergreen', 'BroadleafÂ\xa0evergreen shrub', 'Vine',
#        'PerennialÂ\xa0bulb or corm', 'Perennial, bulb', 'Evergreen',
#        'Shrub, tree', 'Perennial, fruit', 'Vine, perennial',
#        'Annual, perennial', 'Herbaceous, perennial, annual',
#        'Deciduous Tree',
#        'Perennial vegetable, usually grown as an annual',
#        'Perennial, herbaceous', 'Tender perennial, annual',
# ...

# %%
NativeArea =df['Native Area'].unique()

# %%
(NativeArea)
# Out:
# array(['Mediterranean, Asia', 'Pacific Islands, Southeast Asia',
#        'North America, Central America, South America',
#        'North America, Central America', 'Mediterranean area',
#        'Central America', 'Southwestern Asia, Southern Europe',
#        'Tropical south and southeast Asia, Indian subcontinent',
#        'Europe, Asia', 'Africa', 'Asia',
#        'Eastern and Central United States',
#        'North & Central America, Asia', 'South Africa',
#        'Asia and Central Europe', 'Western North America (CA to Mexico)',
#        'North America', 'South America', 'East Asia',
#        'Southeastern United States',
#        'Americas (tropical and subtropical regions)',
#        'Eurasia and North America',
#        'Central America (Mexico, Guatemala, Honduras)',
#        'Europe, North America', 'North America, Caribbean',
#        'North America, Europe, Asia', 'Texas and Mexico',
#        'Tropical regions of the Americas', 'Europe and Asia',
# ...

# %%
america = []
for area in NativeArea:
    if str('North America').lower() and str('South America').lower() and str('Central America').lower() in str(area).lower():
        america.append(area)
len(america)
# Out:
# 41

# %%
america
# Out:
# ['North America, Central America, South America',
#  'North America, Central America',
#  'Central America',
#  'North & Central America, Asia',
#  'Central America (Mexico, Guatemala, Honduras)',
#  'North America, South America, Central America, Europe, Asia, Africa, Mediterranean',
#  'Central America, South America',
#  'Caribbean, Central America, South America',
#  'Central America, North America, South America',
#  'Central America, Europe, North America, South America',
#  'North and Central America',
#  'North America, Central America, South America, Asia',
#  'Central America, South America, and the Caribbean',
#  'South America, Central America',
#  'South and Central America',
#  'North America, Central America (Mexico)',
#  'North America, Central America, Asia',
#  'Central America, Caribbean',
#  'northern South America, Central America, and southern North America',
#  'Central America (Mexico, Guatemala)',
#  'North America, South America, Central America',
# ...

# %%
asiaAndAfrica = []
for area in NativeArea:
    if str('Asia').lower() and str('Africa').lower() in str(area).lower():
        asiaAndAfrica.append(area)
len(asiaAndAfrica)
# Out:
# 78

# %%
asiaAndAfrica
# Out:
# ['Africa',
#  'South Africa',
#  'North America, South America, Central America, Europe, Asia, Africa, Mediterranean',
#  'Europe, Africa',
#  'Warm wetlands of Americas, Asia, Africa',
#  'North Africa and the Middle East',
#  'Asia, Australia, Africa',
#  'Africa, Asia, Europe, Eurasia',
#  'Europe, northern Africa and Asia',
#  'Namibia and South Africa',
#  'Europe, northern Africa to central Asia',
#  'North Africa, Eurasia',
#  'Asia, Europe and North Africa',
#  'Species are from Southern Africa; most are now cultivated hybrids',
#  'South America, Asia, Africa',
#  'Southwest Africa',
#  'Africa, Asia',
#  'Western and southern Europe, northwest Africa, and southwest Asia',
#  'Africa, Asia, North America, South America',
#  'Europe, Africa, Asia, Australia',
#  'Tropical western Africa',
#  'North Africa',
#  'Africa (Madagascar)',
#  'Southern Africa',
#  'Central Africa to Southeast Asia',
#  'Eastern and southern Africa',
# ...

# %%
mena = []
for area in NativeArea:
    if str('western Asia').lower() and str('North Africa').lower() and str('Mediterranean').lower() in str(area).lower():
        mena.append(area)
len(mena)
# Out:
# 19

# %%
mena
# Out:
# ['Mediterranean, Asia',
#  'Mediterranean area',
#  'North America, South America, Central America, Europe, Asia, Africa, Mediterranean',
#  'Europe, Mediterranean',
#  'Mediterranean',
#  'Asia, Mediterranean',
#  'Temperate regions worldwide, especially the Mediterranean',
#  'Europe, especially Mediterranean regions',
#  'TheÂ\xa0eastern Mediterranean',
#  'Southern Europe and the Mediterranean',
#  'Southern Asia and the Mediterranean',
#  'Europe, Africa, Mediterranean',
#  'Europe, Asia, Mediterranean',
#  'Eastern Mediterranean, the Caucasus',
#  'Central Asia and the Mediterranean region',
#  'Mediterranean region',
#  'Mediterranean, Southwest Asia, Southwest Europe',
#  'Mediterranean, Europe, Asia',
#  'Mediterranean and Asia Minor']

# %%
dfMean =df[(df['Native Area'].isin(asiaAndAfrica))]

# %%
dfMean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 171 entries, 10 to 1298
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Common Name      171 non-null    object
#  1   Botanical Name   171 non-null    object
#  2   Family           122 non-null    object
#  3   Plant Type       171 non-null    object
#  4   Size             10 non-null     object
#  5   Sun Exposure     171 non-null    object
#  6   Soil Type        171 non-null    object
#  7   Soil pH          171 non-null    object
#  8   Hardiness Zones  167 non-null    object
#  9   Native Area      171 non-null    object
#  10  image            171 non-null    object
#  11  site             171 non-null    object
#  12  Mature Size      171 non-null    object
#  13  Bloom Time       162 non-null    object
#  14  Flower Color     154 non-null    object
#  15  Toxicity         77 non-null     object
# dtypes: object(16)
# ...

# %% [markdown]
# # Groups The Data

# %% [markdown]
# ### Bloom Time Groups

# %% [markdown]
# #### Winter

# %%
Winter = df[df['Bloom Time'] == 'Winter']

# %%
Winter
# Out:
#                                             Common Name  \
# 16           Monterey pine, insignis pine, radiata pine
# 47    Pink jasmine, white jasmine, Chinese jasmine, ...
# 115                                       Mini cyclamen
# 134                   Velvet plant, purple velvet plant
# 658   Mother of thousands, devil's backbone, alligat...
# 771                      Wintersweet, Japanese allspice
# 859       Poinsettia, Mexican flameleaf, Christmas star
# 888                                               Mango
# 947            Fire lily, natal lily, bush lily, clivia
# 1070                                          Fern tree
# 1147                                      Song of India
# 1184              Kentia palm, thatch palm, sentry palm
#
#                 Botanical Name          Family            Plant Type  \
# 16               Pinus radiata        Pinaceae        Evergreen tree
# 47         Jasminum polyanthum        Oleaceae       Vine, perennial
# ...

# %% [markdown]
# #### WinterSprning

# %%
WinterSprning = ['Winter, Spring','Late winter to early spring','Late winter and spring','Winter, spring','Late winter or spring','Late Winter, Spring','Late winter or early spring']

# %%
dfWinterSprning =df[(df['Bloom Time'].isin(WinterSprning))]

# %%
dfWinterSprning
# Out:
#                                             Common Name  \
# 13                                         Mahonia Spp.
# 67                 Buttercup winter hazel, winter hazel
# 102                  Butcher's broom, horse tongue lily
# 202                                        Protea plant
# 232   Climbing Sea Onion, Climbing Onion, Sea Onionâ...
# 413                                      Weeping willow
# 668                                         Lenten rose
# 686            Ghost echeveria, Mexican hens and chicks
# 755                                           Mistletoe
# 864                   Gasteria, ox tongue, cow's tongue
# 866                                             Aeonium
# 969          Flowering quince, Chinese flowering quince
# 1028                                         Coral aloe
# 1058                     Bird of paradise, crane flower
# 1113                     Bird of paradise, crane flower
# 1259                                Daffodil, narcissus
# ...

# %% [markdown]
# #### Spring

# %%
Spring = ['Spring','March','Early spring, May','March to April','Late spring', 'April','May','Spring; rarely blooms indoors','Early spring','March or April in zone 5','March to June','Mid-spring','Spring (does not bloom indoors)','March and April','April to May','April-May','April, May, and June','Spring (not typically grown for flowers)','Late Spring','Mid to late spring','March, April','Spring (not showy)','Late April','April or May','Spring (rarely flowers indoors)',
'Spring (blooms are rare)', 'April, May','March through to early June','May, early June','Late May to June','late spring; reblooms','March or April','Early Spring', 'Spring (second growing season)',
'Late April to early May','Early to mid-spring', 'May (anthers appear)','March through May','Mayâ\x80\x94primary blooming periodâ\x80\x94till frost','Indoor plants do not bloom, outdoor plants bloom during spring']

# %%
dfSpring =df[(df['Bloom Time'].isin(Spring))]

# %%
dfSpring
# Out:
#                                             Common Name  \
# 4                                           Mastic Tree
# 7     Cornelian cherry dogwood, cornelian cherry,Â E...
# 14                                    String of bananas
# 22                                     Japanese zelkova
# 23                                          Pumpkin ash
# ...                                                 ...
# 1282                                Wintergreen Boxwood
# 1288             Sweet birch, black birch, cherry birch
# 1294                                          Date palm
# 1296  Hoptree, common hoptree, stinking ash, skunk b...
# 1300                             The President clematis
#
#                                          Botanical Name         Family  \
# 4                                    Pistacia lentiscus  Anacardiaceae
# 7                                            Cornus mas            NaN
# 14                 Senecio radicans syn. Curio radicans            NaN
# ...

# %% [markdown]
# #### SpringSummer

# %%
SpringSummer = ['Spring, summer', 'Spring to late summer','Spring to summer','Late spring, early summer','May to June','June','Late spring through summer', 'Spring and summer','Spring, Summer','April to June','Late spring to early summer (flowers are indistinct)','Late spring to early summer; May to June','Late spring to early summer', 'Late spring to mid-summer','Spring to early summer', 'Spring to summer, sometimes early fall and year-round in warmer climates','Late spring/Early summer','Late spring, summer','Spring, summer (very occasional)','Spring, summer (rarely blooms)','Spring to midsummer','Late spring to late summer','Spring, summer (varies by species)', 'Between May and August depending on location',
'Early spring to late summer', 'Sporadically from April to August','Late spring/early summer','Spring and Summer','May to July','Summer (if it blooms)','Usually late spring to early summer; houseplants may vary',]

# %%
dfSpringSummer =df[(df['Bloom Time'].isin(SpringSummer))]

# %%
dfSpringSummer
# Out:
#                                             Common Name  \
# 6                                           Bamboo palm
# 11                                              Kumquat
# 15                                    Daylily, day lily
# 24    Cucamelon, mouse melon, Mexican sour gherkin, ...
# 30    Jade plant, rattlesnake tail, living coral, st...
# ...                                                 ...
# 1269                               Alocasia tiny dancer
# 1271                      Bear's Breeches, Oyster Plant
# 1283               African milk tree, African milk bush
# 1290                    Never never plant, prayer plant
# 1292                     Ashe's Magnolia, Ashe Magnolia
#
#                     Botanical Name         Family  \
# 6            Chamaedorea seifrizii            NaN
# 11                 Citrus japonica       Rutaceae
# 15              HemerocallisÂ spp.      Liliaceae
# 24                Melothria scabra  Cucurbitaceae
# ...

# %% [markdown]
# #### SpringFall

# %%
SpringFall = ['Spring, fall','Spring to fall', 'Late spring to early fall','Mid-spring to early fall','Fall, spring','November through March','Spring to fall (varies by species)','Late spring to fall','Mid-autumn to mid-spring','Late spring to early fall (rarely flowers)', 'June and July','Spring, fall, intermittent','Late fall and then again in late spring; nighttime bloomer']

# %%
dfSpringFall =df[(df['Bloom Time'].isin(SpringFall))]

# %% [markdown]
# #### Summer

# %%
Summer = ['Summer', 'Summer (second year)','June to September','Summer (rarely blooms)','Late Summer','Late spring, early summer, and late summer','Early summer','June through August','Summer (outdoors)','July to September','Summer (rarely flowers)','Midsummer', 'Late July to Early September','Mid to late summer','Mid to late-summer','Mid- to late summer','July','June-July','June to July','Late summer','July to August','Mid to late summer, often blooms until fall','Mid-summer', 'Late June through August','June to August','Summer (flowers are fairly insignificant)','Late July to September', 'July-September', 
'Late June/July','June through September', 'Early to mid summer','Summer (rarely blooms indoors)','SummerÂ\xa0to fall','Varies; usually summer','May (anthers appear)']

# %%
dfSummer =df[(df['Bloom Time'].isin(Summer))]

# %%
dfSummer
# Out:
#                                             Common Name  \
# 1         Cordyline, Hawaiian ti plant, good luck plant
# 5     Red button ginger,Â Indian head ginger, scarle...
# 9                                               Parsnip
# 12    Virginia creeper, Victoria creeper, five-leave...
# 17                                   Becky shasta daisy
# ...                                                 ...
# 1287                Fennel, sweet fennel, common fennel
# 1291                                        Ming aralia
# 1293  Ball cactus, balloon cactus, silver ball cactu...
# 1297       Zigzag plant, red bird flower, fiddle flower
# 1299          Autograph tree, balsam apple, pitch apple
#
#                                          Botanical Name  \
# 1                                  Cordyline terminalis
# 5                                      Costus woodsonii
# 9                                      Pastinaca sativa
# 12                          Parthenocissus quinquefolia
# ...

# %% [markdown]
# #### SummerFall

# %%
SummerFall = ['Summer, fall','Late summer to early fall','June through October','Summer to fall','Early summer to fall','Summer, Fall','Early summer, fruits appear through fall','Late summer and fall', 'Midsummer to late summer and early fall','Summer and early fall','Mid-summer to fall', 'Summer/Fall','Summer, early fall','Late summer, fall','Mid-summer to early fall','August to September', 'Summer/Early fall', 'Late summer through fall','Mid summer through fall','Early summer to mid-fall','Late Summer to Late Fall','Early summer to autumn','Late Summer, Fall','Summer through fall','Late summer, early fall','September to October','June to October','Late summer to fall','Mid-summer, early fall','Summer or early fall','Late summer, Fall','Repeat bloomer, summer through fall','Summer, fall, and year-round in tropical climes','Mid-summer through fall','Midsummer to early fall'  
'Mid-summer, early fall', 'Summer or early fall','Late summer, Fall','Repeat bloomer, summer through fall','Summer, fall, and year-round in tropical climes','Mid-summer through fall','Midsummer to early fall',]

# %%
dfSummerFall =df[(df['Bloom Time'].isin(SummerFall))]

# %%
dfSummerFall
# Out:
#                                             Common Name  \
# 2     Angelâs trumpet, pricklyburr, downy thorn ap...
# 3                                                Dahlia
# 10    Blue Spur Flower, Candlestick Plant, Speckled ...
# 18                                Coneflower, echinacea
# 20    Browallia, Amethyst flower, Bush violet, Sapph...
# ...                                                 ...
# 1255                                       Pampas grass
# 1260                       Heliotrope, cherry pie plant
# 1279  Chinese silver grass, Japanese silver grass, e...
# 1289               Japanese stewartia, common stewartia
# 1295                 Blue beard, blue mist, blue spirea
#
#                                 Botanical Name      Family  \
# 2               DaturaÂ inoxia, Datura innoxia  Solanaceae
# 3                                  Dahlia spp.  Asteraceae
# 10    PlectranthusÂ barbatus,Â Coleus barbatus         NaN
# ...

# %% [markdown]
# #### SpringSummerFall

# %%
SpringSummerFall = ['Spring, summer, fall' , 'Spring, summer, fall (varies according to species)','Spring, Summer, Fall','Spring and mid-summer through fall','March to August','Spring, summer, fall (varies by species)','Spring/Summer/Fall','Late spring, summer, fall','May to October',
'Late spring/summer', 'Summer thru fall']

# %%
dfSpringSummerFall =df[(df['Bloom Time'].isin(SpringSummerFall))]

# %%
dfSpringSummerFall
# Out:
#                                             Common Name  \
# 52                                              Petunia
# 87                                           Nasturtium
# 122      Mexican hat, prairie coneflower, thimbleflower
# 130            Calendula, pot marigold, common marigold
# 149                                   Dendrobium orchid
# 193   Curry tree, curry leaf tree, curry plant, swee...
# 200   Hardy geranium, cranesbill geranium, wild gera...
# 280            Garden balsam, rose balsam, touch-me-not
# 286                                    Hybrid tea roses
# 300                                              Abelia
# 321                             Caladium, elephant ears
# 417                      Crossandra, firecracker flower
# 418   Bougainvillea, lesser bougainvillea, paper flower
# 433   Japanese honeysuckle, Chinese honeysuckle, gol...
# 479                                          Wallflower
# 522              Mexican cigar plant, firecracker plant
# ...

# %%
dfSpringSummerFall.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 52 entries, 52 to 1298
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Common Name      52 non-null     object
#  1   Botanical Name   52 non-null     object
#  2   Family           36 non-null     object
#  3   Plant Type       52 non-null     object
#  4   Size             2 non-null      object
#  5   Sun Exposure     52 non-null     object
#  6   Soil Type        52 non-null     object
#  7   Soil pH          51 non-null     object
#  8   Hardiness Zones  51 non-null     object
#  9   Native Area      51 non-null     object
#  10  image            52 non-null     object
#  11  site             52 non-null     object
#  12  Mature Size      52 non-null     object
#  13  Bloom Time       52 non-null     object
#  14  Flower Color     50 non-null     object
#  15  Toxicity         10 non-null     object
# dtypes: object(16)
# ...

# %% [markdown]
# #### SummerToFrost

# %%
SummerToFrost = ['Summer to frost','June to frost','Early summer to frost','July to frost','Mid-summer through to fall; longer in frost-free climates']

# %%
dfSummerToFrost =df[(df['Bloom Time'].isin(SummerToFrost))]

# %% [markdown]
# #### Fall

# %%
Fall = ['Fall','Autumn','October-November','Cones/berries mature in fall']

# %%
dfFall =df[(df['Bloom Time'].isin(Fall))]

# %%
dfFall
# Out:
#                                             Common Name  \
# 66                English ivy, common ivy, European ivy
# 96                English ivy, common ivy, European ivy
# 271            Purple passion vine, purple velvet plant
# 339   Japanese aralia, Spider's web, Glossy-leaved p...
# 403                                             Joyweed
# 482   Thanksgiving cactus, crab cactus, false Christ...
# 518                                           Sky plant
# 538                                     Silk Floss Tree
# 653   Autumn crocus, meadow saffron, naked ladies, c...
# 693                                Patchouli, pucha pot
# 750                     Pink muhly grass, hairawn muhly
# 897                                     Western juniper
# 941                                   New England aster
# 974                        Tree ivy, bush ivy, ivy tree
# 1237                                  Fatsia Spider Web
# 1277                       Common Ginger, Canton Ginger
#
# ...

# %% [markdown]
# #### FallWinter

# %%
FallWinter = ['Fall, winter','Late fall and early winter','Summer to early fall','Late fall, early winter', 'Fall, winter (does not bloom indoors)', 'Late fall/early winter','Fall, early winter',]

# %%
dfFallWinter =df[(df['Bloom Time'].isin(FallWinter))]

# %%
dfFallWinter
# Out:
#                                             Common Name  \
# 249       Christmas cactus, holiday cactus, crab cactus
# 360   Krantz aloe, Candelabra aloe, torch aloe, tree...
# 365                    Hollyhock mallow, vervain mallow
# 527   Witch hazel, American witch hazel, common witc...
# 732                                          Tiger jaws
# 955        Spur valerian, red valerian, Jupiter's beard
# 958       Loquat tree, Japanese plum, medlar, misbelief
# 960       Lucky bamboo, friendship bamboo, ribbon plant
# 962   Yerba Mate Plant, MatÃ©, Yerba MatÃ¡, Paraguay...
# 1013                 Persian shield, royal purple plant
# 1055                       Living stones, pebble plants
# 1085  Blazing star, liatris, dense blazing star, gay...
# 1118  Mona Lavender, 'Mona Lavender' plectranthus, l...
# 1251                                    Cardinal flower
#
#                     Botanical Name                      Family  \
# ...

# %% [markdown]
# #### SpringToFrost

# %%
SpringToFrost = ['Spring through frost','Spring to frost']

# %%
dfSpringToFrost =df[(df['Bloom Time'].isin(SpringToFrost))]

# %%
dfSpringToFrost
# Out:
#                                             Common Name  Botanical Name  \
# 291   Duranta plant, duranta, golden dewdrops, sky f...  Duranta erecta
# 1153      Million bells, trailing petunia, mini petunia     Calibrachoa
#
#      Family                          Plant Type Size Sun Exposure  \
# 291     NaN  Tropical broadleaf evergreen shrub  NaN         Full
# 1153    NaN        Herbaceous perennial, annual  NaN     Full sun
#
#                             Soil Type  \
# 291   Rich loam; tolerates rocky soil
# 1153       Rich, moist, well-draining
#
#                                       Soil pH Hardiness Zones  \
# 291   Acidic to slightly alkaline (5.6â7.5)  10â11 (USDA)
# 1153                                 5.2 to 6         9 to 11
#
#                     Native Area  \
# 291   Central and South America
# 1153      South American hybrid
#
#                                                   image  \
# 291   https://www.thespruce.com/thmb/EbdmcGqPPpM7bdT...
# ...

# %% [markdown]
# #### FallWinterSpring

# %%
FallWinterSpring = ['Fall, Winter, Spring','Late Winter, Spring, Early Summer','Spring, fall, winter','Spring, winter, fall','Fall, winter, spring','Late fall, winter, early spring','Fall to spring' ]

# %%
dfFallWinterSpring =df[(df['Bloom Time'].isin(FallWinterSpring))]

# %%
dfFallWinterSpring
# Out:
#                                             Common Name  \
# 461                                        Avocado Tree
# 624                  Japanese Camellia, Common Camellia
# 761   Purple shamrock, false shamrock, love plant, s...
# 1036                                        Spur flower
# 1136  Cyclamen, florist's cyclamen, Persian cyclamen...
# 1148                                           Camellia
# 1180                                   Cape honeysuckle
#
#                                          Botanical Name        Family  \
# 461                                    Persea americana     Lauraceae
# 624                                   Camellia Japonica      Theaceae
# 761   Oxalis triangularis (synonymous with Oxalis re...   Oxalidaceae
# 1036                                  Plectranthus spp.     Lamiaceae
# 1136                                  Cyclamen persicum   Primulaceae
# 1148                                      Camellia spp.      Theaceae
# ...

# %% [markdown]
# #### SummerFallWinter

# %%
SummerFallWinter = ['Summer,Fall,Winter' ,'Summer, fall, winter']

# %%
dfSummerFallWinter =df[(df['Bloom Time'].isin(SummerFallWinter))]

# %%
dfSummerFallWinter
# Out:
#                                            Common Name   Botanical Name  \
# 992  Amaranth, amaranthus, love lies bleeding, tass...  Amaranthus spp.
#
#             Family Plant Type Size               Sun Exposure  \
# 992  Amaranthaceae     Annual  NaN  Full sun to partial shade
#
#                   Soil Type          Soil pH Hardiness Zones  \
# 992  Moist but well-drained  Neutral, acidic     2-11 (USDA)
#
#                 Native Area  \
# 992  India, Africa and Peru
#
#                                                  image  \
# 992  https://www.thespruce.com/thmb/r3Zk6uhnCvPIVy8...
#
#                          site                   Mature Size  \
# 992  Amaranth Amaranthus.json  2â4 ft. tall, 1-2 ft. wide
#
#                Bloom Time Flower Color Toxicity
# 992  Summer, fall, winter          Red      NaN

# %% [markdown]
# #### SpringSummerFallWinter

# %%
SpringSummerFallWinter = ['Spring, Summer, Fall, Winter','Spring, Summer, Fall, Winter','Spring, summer, fall, winter']

# %%
dfSpringSummerFallWinter =df[(df['Bloom Time'].isin(SpringSummerFallWinter))]

# %%
dfSpringSummerFallWinter
# Out:
#                                             Common Name  \
# 507                                      Goldfish plant
# 569                               Croton, garden croton
# 843                                New Guinea impatiens
# 920   Dragon fruit, pitahaya, strawberry pear, Honol...
# 1177  Anthurium,Â tailflower, flamingo flower, laceleaf
# 1194                  French lavender, fringed lavender
#
#               Botanical Name         Family             Plant Type  \
# 507   Nematanthus gregarious            NaN              Perennial
# 569      Codiaeum variegatum  Euphorbiaceae                  Shrub
# 843        Impatiens hawkeri  Balsaminaceae                 Annual
# 920       Hylocereus undatus      Cactaceae      Cactus, perennial
# 1177          Anthurium spp.        Araceae  Herbaceous, perennial
# 1194       Lavandula dentata      Lamiaceae              Perennial
#
#                                         Size  \
# 507                                      NaN
# ...

# %% [markdown]
# #### RarelyFlowers

# %%
RarelyFlowers = ['Rarely flowers','Rarely blooms indoors','Rarely flowers indoors','Rarely flowers outside of its native area','Rarely blooms','Rarely blooms, but if it does, it will be between March and April','Rarely blooms indoor']

# %%
dfRarelyFlowers =df[(df['Bloom Time'].isin(RarelyFlowers))]

# %%
dfRarelyFlowers
# Out:
#                                            Common Name  \
# 73               Weeping fig, ficus tree, Benjamin fig
# 105                    Rutabaga, Swedish turnip, swede
# 195                              Round-leaved calathea
# 207                                        Jade Pothos
# 218                Ornamental cabbage, ornamental kale
# 282                         Fiddle-leaf fig, banjo fig
# 285                   Aluminum Plant, Watermelon Pilea
# 334                                Stromanthe triostar
# 807                          Rubber plant, rubber tree
# 886               Ficus Tineke, Variegated rubber tree
# 1217  Pothos, Golden Pothos, Devil's Vine, Devil's Ivy
#
#                                     Botanical Name        Family  \
# 73                                 Ficus benjamina      Moraceae
# 105           Brassica napusÂ (Napobrassica Group)           NaN
# 195   Calathea Orbifolia syn. Geoppertia orbifolia   Marantaceae
# ...

# %% [markdown]
# #### Varies

# %%
Varies = ['Varies','Varies by species','Varies; requires 6 weeks of 14-hour nights','Blooms once; timing varies','Depends on the cultivar']

# %%
dfVaries =df[(df['Bloom Time'].isin(Varies))]

# %%
dfVaries
# Out:
#                                             Common Name  \
# 110                                           Bromeliad
# 125                             Lion's Tail, Wild Dagga
# 148   Cattleya orchid, orchid, corsage orchid, Queen...
# 287        Kalanchoe, flaming Katy, Christmas kalanchoe
# 387                         Senecio (varies by species)
# 904                 Psychopsis orchid, butterfly orchid
# 1073       California lilac, Mountain lilac, Wild lilac
# 1216      Rainbow eucalyptus, rainbow gum, Mindanao gum
#
#                Botanical Name        Family                      Plant Type  \
# 110       Bromeliaceae genera  Bromeliaceae                       Perennial
# 125         Leonotis leonurus     Lamiaceae                           Shrub
# 148                  Cattleya           NaN                       Perennial
# 287   Kalanchoe blossfeldiana  Crassulaceae            Perennial, succulent
# 387              Senecio spp.    Asteraceae            Perennial, succulent
# ...

# %% [markdown]
# #### NonFlowering

# %%
NonFlowering = ['Non-Flowering','No blooms','Non-flowering' ,'Not applicable','Does not bloom',"Doesn't bloom indoors",'Not Applicable','No Bloom','Nonflowering','Not grown for flowers','Flowers not showy','Not grown for its flower']

# %%
dfNonFlowering =df[(df['Bloom Time'].isin(NonFlowering))]

# %%
dfNonFlowering
# Out:
#                                             Common Name  \
# 183                                      Ponderosa pine
# 191   Podocarpus yew pine, Buddhist pine, fern pine,...
# 256                              Green Giant Arborvitae
# 266                                        Foxtail pine
# 337   Emerald green arborvitae, Smaragd arborvitae, ...
# 341                                           Lady fern
# 435              Maidenhair fern, Delta maidenhair fern
# 450                         Staghorn fern, elkhorn fern
# 533   Loblolly pine, bull pine, blue pine, rosemary ...
# 562                                           White Fir
# 573                                    Philodendron Rio
# 626                       Yew bush, yew tree, yew shrub
# 652                                         Rex begonia
# 697         Bloodleaf, chicken gizzard, beefsteak plant
# 783                                        Utah Juniper
# 809                                            Tamarack
# ...

# %% [markdown]
# #### Seasonal

# %%
Seasonal = ['Seasonal','Seasonal bloomer','All season bloom','Seasonal bloomer; blossoms 16 to 18 weeks after seed germination','Cyclical, every few months']

# %%
dfSeasonal =df[(df['Bloom Time'].isin(Seasonal))]

# %%
dfSeasonal
# Out:
#                                             Common Name  \
# 198                              Gardenia, cape jasmine
# 213   Tatsoi, Tah Tsai, Spoon mustard, Spinach musta...
# 217   Yesterday-today-and tomorrow plant, Morning-no...
# 227                      Arugula, rocket, garden rocket
# 400                                Jackfruit, jack tree
# 439                                        Vanda orchid
# 476                         Okra,Â gumbo, lady's finger
# 531                                              Coleus
# 606                      Cineraria, Florist's cineraria
# 660                                      Persian violet
# 825                             Lettuce, garden lettuce
# 909                                           Amaryllis
# 917                     Ponytail palm,Â elephant's foot
# 1064       Boat lily, oyster plant, Moses-in-the-cradle
# 1111                                  Cucumber, gherkin
# 1139                                     Beet, beetroot
# ...

# %% [markdown]
# #### YearRound

# %%
YearRound = ['Year-round','Year-round in frost-free climates','Year-round (rarely flower indoors)','Year-round seasonal bloomer','Year-round when grown in ideal conditions; varies by species.']

# %%
dfYearRound =df[(df['Bloom Time'].isin(YearRound))]

# %%
dfYearRound
# Out:
#                                             Common Name  \
# 383                                           Palm tree
# 423   Princess flower, glory bush, purple glory bush...
# 713                                    Mistletoe cactus
# 1202                             Spiderwort, inch plant
# 1261                             Lantana, shrub verbena
#
#                                          Botanical Name           Family  \
# 383                                    Arecaceae family        Arecaceae
# 423   Tibouchina urvilleana (sometimes categorized a...  Melastomataceae
# 713                                      Rhipsalis spp.              NaN
# 1202                                       Tradescantia    Commelinaceae
# 1261                                     Lantana camara      Verbenaceae
#
#                                      Plant Type Size  \
# 383            Woody perennial trees and shrubs  NaN
# 423     Broadleaf evergreen shrub or small tree  NaN
# ...

# %% [markdown]
# #### OncePerLifetime

# %%
OncePerLife = ['Once per lifetime','Blooms once only','Varies â\x80\x94 most plants only bloom once in their lifetime','Once, when fully matured']

# %%
dfOncePerLife =df[(df['Bloom Time'].isin(OncePerLife))]

# %%
dfOncePerLife
# Out:
#                                          Common Name        Botanical Name  \
# 85    Cryptanthus bromeliad, cryptanthus, earth star      Cryptanthus spp.
# 397                                Bulbous Air Plant    Tillandsia bulbosa
# 549                                        Air plant  Tillandsia cacticola
# 842                                        Air plant    Tillandsia stricta
# 1178                            Agave, century plant                 Agave
# 1247                                       Air plant     Tillandsia kolbii
#
#             Family             Plant Type Size  \
# 85    Bromeliaceae  Terrestrial bromeliad  NaN
# 397            NaN   perennial herbaceous  NaN
# 549            NaN   Houseplant or annual  NaN
# 842            NaN   Houseplant or annual  NaN
# 1178  Asparagaceae   Perennial, succulent  NaN
# 1247           NaN   Houseplant or annual  NaN
#
#                                         Sun Exposure              Soil Type  \
# ...

# %% [markdown]
# ####  ThroughoutTheYear

# %%
ThroughoutTheYear = ['Throughout the year','Periodic through the year']

# %%
dfThroughoutTheYear =df[(df['Bloom Time'].isin(ThroughoutTheYear))]

# %%
dfThroughoutTheYear
# Out:
#                               Common Name         Botanical Name      Family  \
# 680        Cassava, Manioc, Yuca, Tapioca      Manihot esculenta         NaN
# 903  Baby rubber plant, pepper face plant  Peperomia Obtusifolia  Piperaceae
#
#                  Plant Type Size             Sun Exposure  \
# 680  Woody shrub, perennial  NaN  Full sun, partial shade
# 903   Perennial, Herbaceous  NaN                  Partial
#
#                      Soil Type                    Soil pH Hardiness Zones  \
# 680  Sandy, loam, well-drained    Acid, neutral, alkaline     8-12 (USDA)
# 903           Clay, Sand, Loam  Acidic, Neutral, Alkaline    10-12 (USDA)
#
#        Native Area                                              image  \
# 680         Brazil  https://www.thespruce.com/thmb/o90Xa8kD1iwuGVE...
# 903  South America  https://www.thespruce.com/thmb/9yMnpMCy4dZiUdK...
#
#                                              site  \
# 680                Tapioca Manihot esculenta.json
# ...

# %% [markdown]
# #### Just One

# %%
Everyyears = df[df['Bloom Time'] == 'Every 40 to 60 years']

# %%
Everyyears
# Out:
#       Common Name       Botanical Name Family Plant Type Size  \
# 502  Black bamboo  Phyllostachys nigra    NaN      Grass  NaN
#
#                   Sun Exposure                    Soil Type  \
# 502  Full sun to partial shade  Well-draining, moist, loamy
#
#                          Soil pH Hardiness Zones Native Area  \
# 502  Acidic to slightly alkaline    7 to 10, USA        Asia
#
#                                                  image  \
# 502  https://www.thespruce.com/thmb/p9i-OX42-5s94m4...
#
#                                       site              Mature Size  \
# 502  Black Bamboo Phyllostachys nigra.json  30 ft. tall, 2 in. wide
#
#                Bloom Time Flower Color   Toxicity
# 502  Every 40 to 60 years        Brown  Non-toxic

# %%
FlowersFreely = df[df['Bloom Time'] == 'Flowers freely throughout season']

# %%
FlowersFreely
# Out:
#                                            Common Name  \
# 182  Annual geranium, zonal geranium, regal geraniu...
#
#                    Botanical Name Family  \
# 182  Pelargonium spp. and hybrids    NaN
#
#                                             Plant Type Size  \
# 182  Herbaceous perennial flower, usually grown as ...  NaN
#
#                         Sun Exposure  \
# 182  Full sun; tolerates light shade
#
#                                     Soil Type                       Soil pH  \
# 182  Rich, medium-moisture, well-drained soil  Slightly acidic (5.8 to 6.5)
#
#                                   Hardiness Zones  \
# 182  9 to 12 (USDA); grown as an annual elsewhere
#
#                                            Native Area  \
# 182  Species are from Southern Africa; most are now...
#
#                                                  image  \
# 182  https://www.thespruce.com/thmb/oA9Bq1QgujDJeCQ...
#
#                                             site  \
# ...

# %%
VeryOccasional = df[df['Bloom Time'] == 'Very occasional']

# %%
VeryOccasional
# Out:
#                                          Common Name           Botanical Name  \
# 74  Alocasia Black Velvet, Black Velvet Elephant Ear  Alocasia reginula A.Hay
#
#      Family             Plant Type Size Sun Exposure     Soil Type  \
# 74  Araceae  Herbaceous, Perennial  NaN      Partial  Well-drained
#
#           Soil pH Hardiness Zones     Native Area  \
# 74  Acid, Neutral      10+ (USDA)  Southeast Asia
#
#                                                 image  \
# 74  https://www.thespruce.com/thmb/eRpMt6fh4nlYrjT...
#
#                                                  site         Mature Size  \
# 74  Alocasia Black Velvet Alocasia Reginula 'Black...  Up to 1.5 ft. tall
#
#          Bloom Time Flower Color                        Toxicity
# 74  Very occasional        White  Toxic to people, toxic to pets

# %%
Sporadic = df[df['Bloom Time'] == 'Sporadic']

# %%
Sporadic
# Out:
#                                           Common Name          Botanical Name  \
# 43  African spear plant, cylindrical snake plant, ...  Sansevieria cylindrica
#
#    Family Plant Type Size   Sun Exposure            Soil Type  Soil pH  \
# 43    NaN  Succulent  NaN  Full, partial  Sandy, well-drained  Neutral
#
#    Hardiness Zones Native Area  \
# 43  10â11 (USDA)      Africa
#
#                                                 image  \
# 43  https://www.thespruce.com/thmb/wwpdlokKA4nZvFg...
#
#                                                site  \
# 43  African Spear Plant Sansevieria cylindrica.json
#
#                        Mature Size Bloom Time Flower Color  \
# 43  4â6 ft. tall, 1â2 ft. wide   Sporadic        White
#
#                     Toxicity
# 43  Toxic to pets and humans

# %%
AnyTime_warm = df[df['Bloom Time'] == 'Any time of year when temperature is warm enough']

# %%
AnyTime_warm
# Out:
#                                        Common Name    Botanical Name  \
# 535  Chenille flower, monkey tail, red-hot cattail  Acalypha hispida
#
#             Family                                         Plant Type Size  \
# 535  Euphorbiaceae  Evergreen perennial, annual in containers, hou...  NaN
#
#             Sun Exposure         Soil Type  \
# 535  Full to partial sun  Sand, clay, loam
#
#                                     Soil pH Hardiness Zones  \
# 535  Slightly acidic (6.0) to neutral (7.5)          11-Oct
#
#                         Native Area  \
# 535  The Philippines and New Guinea
#
#                                                  image  \
# 535  https://www.thespruce.com/thmb/Z0jV49zWO9q_z74...
#
#                                   site  \
# 535  Monkey Tail Acalypha hispida.json
#
#                                            Mature Size  \
# 535  In tropical climates up to 15 feet tall and 8 ...
#
# ...

# %%
AnyTime = df[df['Bloom Time'] == 'Anytime, but flowers are small']

# %%
AnyTime
# Out:
#                           Common Name     Botanical Name Family  \
# 424  Peacock Plant, Cathedral Windows  Calathea Makoyana    NaN
#
#                            Plant Type Size             Sun Exposure  \
# 424  Evergreen, Herbaceous, Perennial  NaN  Partial Sun, Full Shade
#
#                   Soil Type                           Soil pH Hardiness Zones  \
# 424  Moist but well-drained  Acid, Neutral, Slightly Alkaline    10 - 11, USA
#
#     Native Area                                              image  \
# 424      Brazil  https://www.thespruce.com/thmb/xA-VvijWD09CNMl...
#
#                                      site       Mature Size  \
# 424  Peacock Plant Calathea makoyana.json  Up to 4 ft. tall
#
#                          Bloom Time Flower Color Toxicity
# 424  Anytime, but flowers are small        White      NaN

# %%
SingleFlower = df[df['Bloom Time'] == 'Begins producing a single flower after 10â\x80\x9315 years']

# %%
SingleFlower
# Out:
#                                            Common Name  Botanical Name  \
# 585  Dragon tree, dragon's blood plant, drago, corn...  Dracaena draco
#
#            Family                Plant Type Size            Sun Exposure  \
# 585  Asparagaceae  Broadleaf evergreen tree  NaN  Full sun to part shade
#
#                          Soil Type                      Soil pH  \
# 585  Any well-drained, porous soil  6.0â6.5 (slightly acidic)
#
#     Hardiness Zones                                   Native Area  \
# 585   9â12 (USDA)  The Canary Islands, northwest coastal Africa
#
#                                                  image  \
# 585  https://www.thespruce.com/thmb/RMROtalggeq69G4...
#
#                                 site  \
# 585  Dragon Tree Dracaena draco.json
#
#                                            Mature Size  \
# 585  15â50 ft. outdoors, 3-4 ft. indoors (very sl...
#
#                                             Bloom Time Flower Color  \
# ...

# %%
Species = df[df['Bloom Time'] == 'Species specific']

# %%
Species
# Out:
#        Common Name          Botanical Name       Family Plant Type Size  \
# 1001  Pansy orchid  Miltonia, Miltoniopsis  Orchidaceae  Perennial  NaN
#
#                     Sun Exposure Soil Type Soil pH Hardiness Zones  \
# 1001  Indirect sun to part shade       NaN     NaN     11-12, USDA
#
#                          Native Area  \
# 1001  Brazil, Colombia to Costa Rica
#
#                                                   image  \
# 1001  https://www.thespruce.com/thmb/jdtNM4iB9wNwi6Z...
#
#                                site     Mature Size        Bloom Time  \
# 1001  Miltonia Orchid Miltonia.json  12-20 in. tall  Species specific
#
#                           Flower Color Toxicity
# 1001  Red, yellow, green, white, brown      NaN

# %%
UpTo = df[df['Bloom Time'] == 'Up to 4 times annually']

# %%
UpTo
# Out:
#       Common Name Botanical Name       Family           Plant Type Size  \
# 1015  Zygopetalum    Zygopetalum  Orchidaceae  Perennial, epiphyte  NaN
#
#      Sun Exposure Soil Type Soil pH Hardiness Zones             Native Area  \
# 1015      Partial       NaN     NaN      9-10, USDA  Tropical South America
#
#                                                   image  \
# 1015  https://www.thespruce.com/thmb/oA9Bq1QgujDJeCQ...
#
#                                      site     Mature Size  \
# 1015  Zygopetalum Orchid Zygopetalum.json  12-24 in. tall
#
#                   Bloom Time                          Flower Color Toxicity
# 1015  Up to 4 times annually  Purple, burgundy, green, white, blue      NaN

# %%
df
# Out:
#                                             Common Name  \
# 0                                              Broccoli
# 1         Cordyline, Hawaiian ti plant, good luck plant
# 2     Angelâs trumpet, pricklyburr, downy thorn ap...
# 3                                                Dahlia
# 4                                           Mastic Tree
# ...                                                 ...
# 1296  Hoptree, common hoptree, stinking ash, skunk b...
# 1297       Zigzag plant, red bird flower, fiddle flower
# 1298                            Love-in-a-mist, nigella
# 1299          Autograph tree, balsam apple, pitch apple
# 1300                             The President clematis
#
#                                          Botanical Name         Family  \
# 0                        Brassica oleracea var. italica   Brassicaceae
# 1                                  Cordyline terminalis   Asparagaceae
# 2                        DaturaÂ inoxia, Datura innoxia     Solanaceae
# ...

# %% [markdown]
# ### Sun Exposure Groups

# %% [markdown]
# #### FullSun

# %%
FullSun = ['Full','Full sun (tolerates part shade/light woodland)','Full; 6 to 8 or more hours per day','Full sun; tolerates light shade','Full sun (likes some shade in very hot climates)']

# %%
dfFullSun =df[(df['Sun Exposure'].isin(FullSun))]

# %%
dfFullSun

# %% [markdown]
# #### FullSun_partialSun

# %%
FullSun_partialSun = ['Full-sun, partial sun' ,'Full sun, partial sun','Full, partial','Part shade, Full sun','Full sun to partial sun','Full or partial', 'Full to partial sun','Full sun to part sun','Full to part sun', 'Part sun, sun', 'Full Sun, Partial Sun','Full Sun- Part Shade','Full sun, part sun','Full sun is preferred; partial sun is tolerated']

# %%
dfFullSun_partialSun =df[(df['Sun Exposure'].isin(FullSun_partialSun))]

# %%
dfFullSun_partialSun

# %% [markdown]
# #### FullSun_PartialShade

# %%
FullSun_PartialShade = ['Full sun, Partial Shade','Full sun to part shade','Sun to partial shade', 'Full sun, partial shade','Full sun to partial shade','Full sun to light/part shade','Full sun, Partial shade', 'Full sun / partial shade','Full sun to shade','Full Sun- Part Shade','Full sun, part shade','Full sun, partial shade, full shade','Full Sun to Part Shade','Full sun/ partial shade']

# %%
dfFullSun_PartialShade =df[(df['Sun Exposure'].isin(FullSun_PartialShade))]

# %%
dfFullSun_PartialShade

# %% [markdown]
# #### PartialSun_partialShade

# %%
PartialSun_partialShade = ['Partial sun to partial shade','Partial, shade','Partial, Full','Full, Partial', 'Part Sun/Part Shade',Partial sun, morning sun','Partial sun to dappled shade','Full sun to light shade','Shade to partial sun','Partial to Full','Partial sun to shade','Part sun']

# %%
dfPartialSun_partialShade =df[(df['Sun Exposure'].isin(PartialSun_partialShade))]

# %%
dfPartialSun_partialShade

# %% [markdown]
# #### Partial

# %%
Partial = ['Partial','Partial (outdoor); bright, indirect light (indoors)','Partial Shade','Full, Partial, Shade', 'Partial shade','Partial, full','Shade']

# %%
dfPartial =df[(df['Sun Exposure'].isin(Partial))]

# %%
dfPartial

# %% [markdown]
# #### PartialShade_FullShade

# %%
PartialShade_FullShade = ['Partial shade to full shade','Part shade to full shade','Partial to full shade','Partial shade, shade', 'Part shade','Full, partial (varies according to variety)','Part shade, shade','Partial, full shade','Full to Part Shade']

# %%
dfPartialShade_FullShade =df[(df['Sun Exposure'].isin(PartialShade_FullShade))]

# %%
dfPartialShade_FullShade

# %% [markdown]
# #### BrightIndirect

# %%
BrightIndirect = ['Bright, indirect light','Filtered, bright sun','Bright indirect light; resents direct sunlight','Bright indirect light','Bright, indirect late to shade','Bright light - partial shade','Indirect light (indoors), full to partial shade (outdoors)','At least four hours of indirect, sun a day']

# %%
dfBrightIndirect =df[(df['Sun Exposure'].isin(BrightIndirect))]

# %%
dfBrightIndirect

# %% [markdown]
# #### ShadeSummer

# %%
ShadeSummer = ['Shade in summer and sun in winter','Shade in summer and sun in winter']

# %%
dfShadeSummer =df[(df['Sun Exposure'].isin(ShadeSummer))]

# %%
dfShadeSummer

# %% [markdown]
# ### Plant Type Groups

# %% [markdown]
# #### Herbs

# %%
Herbs = ['Herbaceous, perennial','Perennial, herbaceous','Perennial, herbaceous, rhizome','Herbaceous, perennial, annual','Herbaceous, Perennial','Tropical herb','Herbaceous perennial','Herbaceous perennial, rhizome','Herbaceous perennials','Herbaceous vine, Perennial','Herb, Annual','Native herbaceous perennial','Herbaceous perennial; usually grown as an annual','Herbaceous perennial flower, usually grown as an annual','Herbaceous, biennial','Perennial, Herbaceous','Perennial herb','Perennial, herb','Herbaceous flowering perennial','Perennial, annual, herbaceous','Herbaceous annual','Herbaceous perennial, often grown as an annual','Evergreen, herbaceous','Perennial or annual herb','Biennial, Herbaceous','Perennial, groundcover, herbaceous','Herbaceous perennial flower often grown as an annual','Perennial, Herb','Annual, herbaceous','perennial herbaceous','Perennial, annual, biennial, herbaceous','Evergreen, Herbaceous, Perennial','Herbaceous perennial (usually grown as an annual)','Herbaceous, evergreen, rhizomatous perennial','Annual herb','Herbaceous perennial, usually grown as an annual','Herbaceous, perennial vine','Annual, biennial, herbaceous','Herbaceous,Â\xa0perennial (sometimes grown as annuals)','Perennial, annual, herb', 'Herbaceous, perennial, biennial','Herb','Annual, herb','Herbaceous Perennial','Herbaceous, with aÂ\xa0perennialÂ\xa0life cycle','Herbaceous, annual','Herbaceous perennial, native wildflower','Herbaceous, evergreen, perennial','Herbaceous, Perennial,Biennial','Herbaceous perennial, often grown as a houseplant','HerbaceousÂ\xa0perennial','Herbacious perennial','Herbaceous annual (perennial in zones 10â\x80\x9311)','HerbaceousÂ\xa0biennial', 'Herb, perennial','Herbaceous, perennial, corm','Annual and perennial herbaceous plants','Carnivorous', 'Herbaceous biennial','Perennial, annual, biennial','Herbaceous plant with a perennial life cycle','Herbaceous perennial wildflower','Herbaceous perennial, annual']

# %%
dfHerbs =df[(df['Plant Type'].isin(Herbs))]

# %%
dfHerbs

# %% [markdown]
# #### Shrubs

# %%
Shrubs = ['Shrub','Broadleaf, deciduous, shrub','DeciduousÂ\xa0flowering shrub','Deciduous shrub','Perennial,shrub','Deciduous fruiting shrub','Evergreen shrub, groundcover','Flowering shrub','Flowering broadleaf evergreen shrub','Perennial shrub','Succulent evergreen shrub,houseplant','Perennial, fruit, shrub', 'Tropical broadleaf evergreen shrub','Flowering deciduous shrub','Deciduous flowering shrub','Decicuous shrub','Deciduous Shrub','Broadleaf evergreen shrub or small tree','Shrub, tree, rhizome','Herbaceous perennial, or woody shrub','Shrub, perennial','Shrub, rose','Perennial, shrub, rose','Broadleaf evergreen shrub','Shrub, Evergreen','Flower, shrub','Woody shrub, perennial', 'Shrub, annual','Broadleaf, evergreen shrub','Deciduous shrub with a vine-like growth habit','Annual, fruit, shrub','Perennial, Tree, Shrub, Fruit','Perennial, evergreen, shrub','Deciduous, Shrub','Evergreen flowering shrub','Evergreen shrub','Perennial, Shrub', 'Broadleaf evergreen shrub or tree','Deciduous or evergreen shrub','Evergreen, tree, shrub','Perennial, annual, groundcover, shrub','Shrub, groundcover','Evergreen and deciduous shrubs','Deciduous shrub or woody perennial','Semi-woody shrub, often planted as an annual','Evergreen perennial/shrub, often grown as an annual','Perennial, "subshrub"']

# %%
dfShrubs =df[(df['Plant Type'].isin(Shrubs))]

# %%
dfShrubs

# %% [markdown]
# #### Trees

# %%
Trees = ['Tree','Deciduous Tree','Evergreen tree usually grown as a houseplant','Deciduous tree','Fruit, tree, perennial','Coniferous tree','Deciduous fruit tree','Coniferous, evergreen','Fruit tree','Evergreen tree (conifer)','Flowering fruit tree','Tree,Â\xa0shrub','Flowering deciduous tree', 'Coniferous, needled, evergreen tree','Perennial deciduous tree','Evergreen, coniferous tree','Tree, Fruit','Flowering tree','Ornamental tree', 'Evergreen fruit tree','Evergreen, Tree','Perennial, Tree','Tree, fruit','Broadleaf evergreen tree', 'Coniferous evergreen tree','Tree, deciduous','Broadleaf, deciduous tree','Evergreen citrus tree', 'Spice, Tree','Perennial, tree','Broadleaf, deciduousÂ\xa0tree','Tree, Perennial','Tree, cycad','Evergreen pine tree','Woody Perennial, Evergreen, Tree-like','Deciduous shrub or tree','Tree, evergreen','Deciduous flowering tree']

# %%
dfTrees =df[(df['Plant Type'].isin(Trees))]

# %%
dfTrees

# %% [markdown]
# #### TreesShrubs

# %%
TreesShrubs = ['Evergreen Tree or shrub','Woody perennial trees and shrubs','Deciduous shrub or small tree','Broadleaf, evergreen, shrub/tree','Deciduous shrub/ tree','Shrub, tree','Tree, shrub','Blooming evergreen shrub or tree','Deciduous tree, shrub','Shrub (broadleaf evergreen)','Evergreen coniferous tree','Evergreen shrub/tree', 'Flowering tree, large shrub','Deciduous tree / large shrub','Tree, Shrub','Coniferous shrub, tree','Broadleaf evergreen shrub/ tree','Evergreen tree/shrub','Tree or large shrub','Needled evergreen tree often trimmed to be shrub-like','Deciduous tree/shrub']

# %% [markdown]
# #### Climbers

# %%
Climbing = ['Perennial, evergreen climbing vine','Climbing evergreen']

# %% [markdown]
# #### Vegetable

# %%
Vegetable = ['Vegetable','Biennial, vegetable','Biennial, annual, vegetable','Perennial vegetable, usually grown as an annual','Perennial, vegetable','Vegetable, perennial, annual','Root vegetable','Annual, vegetable','Vegetable, annual','Climbing vegetable vine','Annual vegetable','Vegetable, perennial','Biennial vegetable (usually grown as annual)','Annual, biennial, vegetable','Perennial vegetable; usually grown as an annual','Annual tuberous vegetable','Vegetable, biennial, annual','Annual vegetable plant','Perennial (commonly grown as annual), vegetable','Perennial vegetable','Bulb, vegetable','Biennial vegetable; usually grown as an annual']

# %% [markdown]
# #### Palms

# %%
Palms = ['Palm','Perennial, clustered parlour palm, reed palm, cane palm','Palm or cycad','Palm tree']

# %% [markdown]
# #### HerbsShrubs

# %%
HerbsShrubs = ['Herbaceous perennial, subshrub','Herbaceous, perennial, shrub','Shrub, herbaceous, perennial, annual','Tender Perennial, Subshrub, Herbaceous','Herbaceous perennial shrub','Shrub, herbaceous, perennial','Perennial, shrub, herb','Herbaceous shrub','Perennial, Herbaceous Shrub']

# %% [markdown]
# ####  Fruit

# %%
Fruit = ['Fruit','Annual, fruit','Perennial, fruit','Fruit, annual','Fruit-bearing, deciduous groundcover','fruiting vine','Fruit, perennial']

# %% [markdown]
# #### FruitVegetable

# %%
FruitVegetable = ['Fruit/vegetable']

# %% [markdown]
# #### FruitTree

# %%
FruitTree = ['Fruit, tree']

# %% [markdown]
# #### HerbVegetable

# %%
HerbVegetable = ['Perennial, herb, vegetable']

# %% [markdown]
# #### Vine

# %%
Vine = ['Vine','Woody perennia vine','Perennial, Vine','Vine, perennial','Perennial vine (typically grown as an annual)','Perennial, vine','Deciduous, perennial vine','Perennial vine (sometimes grown as an annual)', 'Evergreen, vine','Evergreen, perennial, vine','Perennial vine','Annual vine','Perennial, annual, vine', 'Evergreen vine','Tropical perennial vine','Tender perennial, vine','Perennial flowering vine', 'Deciduous perennial flowering vine']

# %% [markdown]
# #### Orchid

# %%
Orchid = ['Orchid','Epiphytic orchids']

# %% [markdown]
# #### Mushroom

# %%
Mushroom = ['Sac fungi (mushroom)']

# %% [markdown]
# #### Succulent

# %%
Succulent = ['Succulent','Semi-succulent','Succulent, perennial','Perennial succulent/cacti','Perennial, succulent','Perennial, Succulent','Succulent, rhizome','Succulent, evergreen perennial','Evergreen succulent','Deciduous succulent (not related to true palms)','Succulent perennial', 'Perennial succulent','Succulent, Vine, Evergreen','Vine, succulent','Tropical succulent','Bulb, vine, succulent','Perennial, Succulent, Vine']

# %% [markdown]
# #### SucculentCactus

# %%
SucculentCactus = ['Cactus, perennial, succulent','Succulent, cactus, perennial','Cactus/Succulent']

# %% [markdown]
# #### Cactus

# %%
Cactus = ['Perennial, cactus','Cactus, perennial','Bulb','Cactus']

# %% [markdown]
# #### Grass

# %%
Grass =['Grass','Ornamental perennial grass','Deciduous Grass','Annual ornamental grass, tender perennial in warmer climates','Ornamental grass','Perennial grass','Perennial, grass']

# %% [markdown]
# #### HerbsCactus

# %%
HerbsCactus = ['Herbaceous, perennial, cactus']

# %% [markdown]
# #### HerbsSucculent

# %%
HerbsSucculent = ['Herbaceous, perennial, succulent','Flowering succulents; herbaceous perennials and annuals; houseplants']
